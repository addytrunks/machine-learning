# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
# Polynomial regression = Combination of Linear Regression with only one feauture(column) that is powered multiple times
# y = c + b1X1 + b2X1^2 + b3X1^3 ..... + bnN1^n

from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)

# Creating multiple feautures
X_poly = poly_reg.fit_transform(X)

# Integrating the new matrix of feautures to Linear Reg Model
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
#Original Values
plt.scatter(X,y,color="red")

# Predicted Values
plt.plot(X,lin_reg.predict(X))

plt.title('Truth or Bluff')
plt.xlabel('Position Level')
plt.ylabel('Salary')

# The model is clearly not adapted to the dataset, which means that Linear Regression is not the right choice
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
#Original Values
plt.scatter(X,y,color="red")

# Predicted Values
plt.plot(X,lin_reg_2.predict(X_poly))

plt.title('Truth or Bluff')
plt.xlabel('Position Level')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
# lin_reg_2.predict([[6.5]])
# The above statement doesn't work because the polynomial regressor takes in new matrix of feautures that are powered

lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265153])
